# %%
# !pip install pygame
# Out:
# Collecting pygame
#   Downloading pygame-2.6.1-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Downloading pygame-2.6.1-cp311-cp311-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.6 MB 1.7 MB/s eta 0:00:07
#    - -------------------------------------- 0.5/10.6 MB 1.7 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/10.6 MB 1.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.3/10.6 MB 1.3 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.6/10.6 MB 1.4 MB/s eta 0:00:07
#    -------- ------------------------------- 2.4/10.6 MB 1.7 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.9/10.6 MB 1.9 MB/s eta 0:00:05
#    ------------- -------------------------- 3.7/10.6 MB 2.1 MB/s eta 0:00:04
#    --------------- ------------------------ 4.2/10.6 MB 2.2 MB/s eta 0:00:03
#    ------------------ --------------------- 5.0/10.6 MB 2.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.0/10.6 MB 2.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.3/10.6 MB 2.6 MB/s eta 0:00:02
#    --------------------------- ------------ 7.3/10.6 MB 2.6 MB/s eta 0:00:02
#    ------------------------------- -------- 8.4/10.6 MB 2.8 MB/s eta 0:00:01
#    --------------------------------- ------ 8.9/10.6 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 9.7/10.6 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.6 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 2.9 MB/s  0:00:03
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1

# %%
# !pip install tensorboard
# Out:
# Collecting tensorboard
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: absl-py>=0.4 in c:\drl_final_project\drl_env\lib\site-packages (from tensorboard) (2.3.1)
# Collecting grpcio>=1.48.2 (from tensorboard)
#   Downloading grpcio-1.76.0-cp311-cp311-win_amd64.whl.metadata (3.8 kB)
# Collecting markdown>=2.6.8 (from tensorboard)
#   Downloading markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.12.0 in c:\drl_final_project\drl_env\lib\site-packages (from tensorboard) (2.3.5)
# Requirement already satisfied: packaging in c:\drl_final_project\drl_env\lib\site-packages (from tensorboard) (25.0)
# Requirement already satisfied: pillow in c:\drl_final_project\drl_env\lib\site-packages (from tensorboard) (12.0.0)
# Collecting protobuf!=4.24.0,>=3.19.6 (from tensorboard)
#   Downloading protobuf-6.33.2-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: setuptools>=41.0.0 in c:\drl_final_project\drl_env\lib\site-packages (from tensorboard) (80.9.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard)
#   Downloading werkzeug-3.1.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: typing-extensions~=4.12 in c:\drl_final_project\drl_env\lib\site-packages (from grpcio>=1.48.2->tensorboard) (4.15.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\drl_final_project\drl_env\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/5.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.5 MB 1.4 MB/s eta 0:00:04
#    --- ------------------------------------ 0.5/5.5 MB 1.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 0.8/5.5 MB 1.2 MB/s eta 0:00:04
#    ------- -------------------------------- 1.0/5.5 MB 1.2 MB/s eta 0:00:04
#    --------- ------------------------------ 1.3/5.5 MB 1.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 1.6/5.5 MB 1.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 1.6/5.5 MB 1.1 MB/s eta 0:00:04
#    ------------- -------------------------- 1.8/5.5 MB 1.1 MB/s eta 0:00:04
#    --------------- ------------------------ 2.1/5.5 MB 1.0 MB/s eta 0:00:04
#    ----------------- ---------------------- 2.4/5.5 MB 1.1 MB/s eta 0:00:03
#    ------------------ --------------------- 2.6/5.5 MB 1.1 MB/s eta 0:00:03
#    -------------------- ------------------- 2.9/5.5 MB 1.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.1/5.5 MB 1.1 MB/s eta 0:00:03
#    ------------------------ --------------- 3.4/5.5 MB 1.1 MB/s eta 0:00:02
#    -------------------------- ------------- 3.7/5.5 MB 1.1 MB/s eta 0:00:02
#    ------------------------------ --------- 4.2/5.5 MB 1.2 MB/s eta 0:00:02
#    ------------------------------ --------- 4.2/5.5 MB 1.2 MB/s eta 0:00:02
#    -------------------------------- ------- 4.5/5.5 MB 1.1 MB/s eta 0:00:01
#    -------------------------------- ------- 4.5/5.5 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.7/5.5 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------ --- 5.0/5.5 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 5.2/5.5 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 1.1 MB/s  0:00:05
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading grpcio-1.76.0-cp311-cp311-win_amd64.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.7 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.7 MB 932.9 kB/s eta 0:00:05
#    ---- ----------------------------------- 0.5/4.7 MB 932.9 kB/s eta 0:00:05
#    ------ --------------------------------- 0.8/4.7 MB 882.6 kB/s eta 0:00:05
#    -------- ------------------------------- 1.0/4.7 MB 931.8 kB/s eta 0:00:04
#    -------- ------------------------------- 1.0/4.7 MB 931.8 kB/s eta 0:00:04
#    ----------- ---------------------------- 1.3/4.7 MB 808.5 kB/s eta 0:00:05
#    ----------- ---------------------------- 1.3/4.7 MB 808.5 kB/s eta 0:00:05
#    ------------- -------------------------- 1.6/4.7 MB 742.6 kB/s eta 0:00:05
#    ------------- -------------------------- 1.6/4.7 MB 742.6 kB/s eta 0:00:05
#    --------------- ------------------------ 1.8/4.7 MB 751.1 kB/s eta 0:00:04
#    --------------- ------------------------ 1.8/4.7 MB 751.1 kB/s eta 0:00:04
#    ----------------- ---------------------- 2.1/4.7 MB 734.0 kB/s eta 0:00:04
#    ----------------- ---------------------- 2.1/4.7 MB 734.0 kB/s eta 0:00:04
#    -------------------- ------------------- 2.4/4.7 MB 729.4 kB/s eta 0:00:04
#    ---------------------- ----------------- 2.6/4.7 MB 732.9 kB/s eta 0:00:03
#    ---------------------- ----------------- 2.6/4.7 MB 732.9 kB/s eta 0:00:03
#    ------------------------ --------------- 2.9/4.7 MB 711.0 kB/s eta 0:00:03
#    ------------------------ --------------- 2.9/4.7 MB 711.0 kB/s eta 0:00:03
#    -------------------------- ------------- 3.1/4.7 MB 723.8 kB/s eta 0:00:03
#    ---------------------------- ----------- 3.4/4.7 MB 729.5 kB/s eta 0:00:02
#    ---------------------------- ----------- 3.4/4.7 MB 729.5 kB/s eta 0:00:02
#    ------------------------------- -------- 3.7/4.7 MB 744.4 kB/s eta 0:00:02
#    --------------------------------- ------ 3.9/4.7 MB 750.5 kB/s eta 0:00:02
#    ----------------------------------- ---- 4.2/4.7 MB 774.4 kB/s eta 0:00:01
#    ------------------------------------- -- 4.5/4.7 MB 794.2 kB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 801.7 kB/s  0:00:05
# Downloading markdown-3.10-py3-none-any.whl (107 kB)
# Downloading protobuf-6.33.2-cp310-abi3-win_amd64.whl (436 kB)
# Downloading werkzeug-3.1.4-py3-none-any.whl (224 kB)
# Installing collected packages: werkzeug, tensorboard-data-server, protobuf, markdown, grpcio, tensorboard
#
#    ---------------------------------------- 0/6 [werkzeug]
#    ---------------------------------------- 0/6 [werkzeug]
#    ---------------------------------------- 0/6 [werkzeug]
#    ---------------------------------------- 0/6 [werkzeug]
#    ---------------------------------------- 0/6 [werkzeug]
#    ---------------------------------------- 0/6 [werkzeug]
#    ---------------------------------------- 0/6 [werkzeug]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    ------------- -------------------------- 2/6 [protobuf]
#    -------------------- ------------------- 3/6 [markdown]
#    -------------------- ------------------- 3/6 [markdown]
#    -------------------- ------------------- 3/6 [markdown]
#    -------------------- ------------------- 3/6 [markdown]
#    -------------------- ------------------- 3/6 [markdown]
#    -------------------- ------------------- 3/6 [markdown]
#    -------------------------- ------------- 4/6 [grpcio]
#    -------------------------- ------------- 4/6 [grpcio]
#    -------------------------- ------------- 4/6 [grpcio]
#    -------------------------- ------------- 4/6 [grpcio]
#    -------------------------- ------------- 4/6 [grpcio]
#    -------------------------- ------------- 4/6 [grpcio]
#    -------------------------- ------------- 4/6 [grpcio]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    --------------------------------- ------ 5/6 [tensorboard]
#    ---------------------------------------- 6/6 [tensorboard]
#
# Successfully installed grpcio-1.76.0 markdown-3.10 protobuf-6.33.2 tensorboard-2.20.0 tensorboard-data-server-0.7.2 werkzeug-3.1.4

# %%
import os
import numpy as np
import gymnasium as gym
import register_envs
import pygame

from stable_baselines3 import SAC
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.evaluation import evaluate_policy
# Out:
# /mnt/data/MyDrive/RKMVERI/RL/Final Project/rl-fetch/lib/python3.12/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
def make_env():
    env = env = gym.make("BallPlate-v0", render_mode=None)
    env = Monitor(env)   # records episode reward & length
    return env

env = make_vec_env(make_env, n_envs=1)

# %%
print("Action Space:", env.action_space)
print("Observation Space:", env.observation_space)
# Out:
# Action Space: Box(-1.0, 1.0, (2,), float32)
# Observation Space: Box(-inf, inf, (6,), float32)

# %%
model = SAC(
    policy="MlpPolicy",
    env=env,

    learning_rate=3e-4,
    buffer_size=200_000,
    learning_starts=5_000,

    batch_size=256,
    tau=0.005,
    gamma=0.99,

    train_freq=1,
    gradient_steps=1,

    ent_coef="auto",
    verbose=1,
    tensorboard_log="./sac_ballplate_tensorboard/"
)
# Out:
# Using cuda device

# %%
TOTAL_TIMESTEPS = 300_000
model.learn(total_timesteps=TOTAL_TIMESTEPS)
# Out:
# Logging to ./sac_ballplate_tensorboard/SAC_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.2     |
# |    ep_rew_mean     | -86.7    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 1883     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 197      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.6     |
# |    ep_rew_mean     | -90.3    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 1969     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 381      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.2     |
# |    ep_rew_mean     | -69.5    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 2243     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1023     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.5     |
# |    ep_rew_mean     | -72.5    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 2281     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1352     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85       |
# |    ep_rew_mean     | -71.8    |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 2265     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 86.4     |
# |    ep_rew_mean     | -70.2    |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 2214     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2073     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.6     |
# |    ep_rew_mean     | -70.7    |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 2174     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2396     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.4     |
# |    ep_rew_mean     | -72.4    |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 2220     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2668     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.4     |
# |    ep_rew_mean     | -70.9    |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 2200     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3038     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 86.7     |
# |    ep_rew_mean     | -69      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 2220     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3468     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.2     |
# |    ep_rew_mean     | -71.8    |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 2203     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3571     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.3     |
# |    ep_rew_mean     | -72      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 2244     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 3949     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.4     |
# |    ep_rew_mean     | -71.6    |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 2259     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4235     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 80       |
# |    ep_rew_mean     | -72.1    |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 2242     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 4478     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.4     |
# |    ep_rew_mean     | -70.7    |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 1611     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 5006     |
# | train/             |          |
# |    actor_loss      | -1.36    |
# |    critic_loss     | 198      |
# |    ent_coef        | 0.999    |
# |    ent_coef_loss   | -0.00403 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5        |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.5     |
# |    ep_rew_mean     | -69.4    |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 460      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 5406     |
# | train/             |          |
# |    actor_loss      | -2.77    |
# |    critic_loss     | 3.15     |
# |    ent_coef        | 0.888    |
# |    ent_coef_loss   | -0.371   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 405      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.6     |
# |    ep_rew_mean     | -69.7    |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 300      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 5754     |
# | train/             |          |
# |    actor_loss      | -2.06    |
# |    critic_loss     | 71.6     |
# |    ent_coef        | 0.805    |
# |    ent_coef_loss   | -0.644   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 753      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.6     |
# |    ep_rew_mean     | -70.7    |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 256      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 5946     |
# | train/             |          |
# |    actor_loss      | -1.42    |
# |    critic_loss     | 153      |
# |    ent_coef        | 0.761    |
# |    ent_coef_loss   | -0.829   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 945      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.5     |
# |    ep_rew_mean     | -71.2    |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 219      |
# |    time_elapsed    | 28       |
# |    total_timesteps | 6196     |
# | train/             |          |
# |    actor_loss      | -2.83    |
# |    critic_loss     | 59.2     |
# |    ent_coef        | 0.709    |
# |    ent_coef_loss   | -0.967   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1195     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.4     |
# |    ep_rew_mean     | -71.3    |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 185      |
# |    time_elapsed    | 35       |
# |    total_timesteps | 6513     |
# | train/             |          |
# |    actor_loss      | -3.04    |
# |    critic_loss     | 85.3     |
# |    ent_coef        | 0.649    |
# |    ent_coef_loss   | -1.12    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1512     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.9     |
# |    ep_rew_mean     | -70.7    |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 158      |
# |    time_elapsed    | 43       |
# |    total_timesteps | 6964     |
# | train/             |          |
# |    actor_loss      | -2.03    |
# |    critic_loss     | 135      |
# |    ent_coef        | 0.572    |
# |    ent_coef_loss   | -1.42    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1963     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.3     |
# |    ep_rew_mean     | -70.2    |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 139      |
# |    time_elapsed    | 53       |
# |    total_timesteps | 7416     |
# | train/             |          |
# |    actor_loss      | -2.02    |
# |    critic_loss     | 67.5     |
# |    ent_coef        | 0.506    |
# |    ent_coef_loss   | -1.72    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2415     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 86       |
# |    ep_rew_mean     | -69.1    |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 124      |
# |    time_elapsed    | 63       |
# |    total_timesteps | 7909     |
# | train/             |          |
# |    actor_loss      | -4.66    |
# |    critic_loss     | 45.2     |
# |    ent_coef        | 0.442    |
# |    ent_coef_loss   | -2.05    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2908     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.7     |
# |    ep_rew_mean     | -68.3    |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 113      |
# |    time_elapsed    | 74       |
# |    total_timesteps | 8423     |
# | train/             |          |
# |    actor_loss      | -0.968   |
# |    critic_loss     | 50       |
# |    ent_coef        | 0.385    |
# |    ent_coef_loss   | -1.98    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3422     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.4     |
# |    ep_rew_mean     | -67.8    |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 107      |
# |    time_elapsed    | 82       |
# |    total_timesteps | 8843     |
# | train/             |          |
# |    actor_loss      | -3.86    |
# |    critic_loss     | 20       |
# |    ent_coef        | 0.344    |
# |    ent_coef_loss   | -2.08    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3842     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.4     |
# |    ep_rew_mean     | -66.8    |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 102      |
# |    time_elapsed    | 90       |
# |    total_timesteps | 9236     |
# | train/             |          |
# |    actor_loss      | -1.77    |
# |    critic_loss     | 13.5     |
# |    ent_coef        | 0.31     |
# |    ent_coef_loss   | -2.27    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4235     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92       |
# |    ep_rew_mean     | -66.2    |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 98       |
# |    time_elapsed    | 97       |
# |    total_timesteps | 9585     |
# | train/             |          |
# |    actor_loss      | -1.24    |
# |    critic_loss     | 20.6     |
# |    ent_coef        | 0.283    |
# |    ent_coef_loss   | -2.44    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4584     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89       |
# |    ep_rew_mean     | -67.6    |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 95       |
# |    time_elapsed    | 103      |
# |    total_timesteps | 9924     |
# | train/             |          |
# |    actor_loss      | -2.48    |
# |    critic_loss     | 3.76     |
# |    ent_coef        | 0.258    |
# |    ent_coef_loss   | -2.47    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4923     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.9     |
# |    ep_rew_mean     | -67.1    |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 92       |
# |    time_elapsed    | 110      |
# |    total_timesteps | 10242    |
# | train/             |          |
# |    actor_loss      | -3.93    |
# |    critic_loss     | 8.06     |
# |    ent_coef        | 0.237    |
# |    ent_coef_loss   | -2.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5241     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89.9     |
# |    ep_rew_mean     | -66.5    |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 89       |
# |    time_elapsed    | 119      |
# |    total_timesteps | 10689    |
# | train/             |          |
# |    actor_loss      | -2.29    |
# |    critic_loss     | 19.7     |
# |    ent_coef        | 0.211    |
# |    ent_coef_loss   | -2.85    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5688     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89.8     |
# |    ep_rew_mean     | -66.6    |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 86       |
# |    time_elapsed    | 128      |
# |    total_timesteps | 11057    |
# | train/             |          |
# |    actor_loss      | -0.8     |
# |    critic_loss     | 45.9     |
# |    ent_coef        | 0.192    |
# |    ent_coef_loss   | -2.96    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6056     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.6     |
# |    ep_rew_mean     | -65.5    |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 82       |
# |    time_elapsed    | 142      |
# |    total_timesteps | 11753    |
# | train/             |          |
# |    actor_loss      | 0.193    |
# |    critic_loss     | 26.6     |
# |    ent_coef        | 0.164    |
# |    ent_coef_loss   | -2.02    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6752     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.8     |
# |    ep_rew_mean     | -63.8    |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 80       |
# |    time_elapsed    | 152      |
# |    total_timesteps | 12245    |
# | train/             |          |
# |    actor_loss      | 1.98     |
# |    critic_loss     | 22.1     |
# |    ent_coef        | 0.148    |
# |    ent_coef_loss   | -1.59    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7244     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.8     |
# |    ep_rew_mean     | -65      |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 78       |
# |    time_elapsed    | 160      |
# |    total_timesteps | 12620    |
# | train/             |          |
# |    actor_loss      | -0.711   |
# |    critic_loss     | 9.76     |
# |    ent_coef        | 0.137    |
# |    ent_coef_loss   | -1.18    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7619     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.4     |
# |    ep_rew_mean     | -65.6    |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 77       |
# |    time_elapsed    | 168      |
# |    total_timesteps | 13011    |
# | train/             |          |
# |    actor_loss      | 4.15     |
# |    critic_loss     | 2.97     |
# |    ent_coef        | 0.126    |
# |    ent_coef_loss   | -1.61    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8010     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -63.3    |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 75       |
# |    time_elapsed    | 179      |
# |    total_timesteps | 13584    |
# | train/             |          |
# |    actor_loss      | -0.634   |
# |    critic_loss     | 3.02     |
# |    ent_coef        | 0.112    |
# |    ent_coef_loss   | -1.05    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8583     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -63.2    |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 74       |
# |    time_elapsed    | 187      |
# |    total_timesteps | 13966    |
# | train/             |          |
# |    actor_loss      | -2.29    |
# |    critic_loss     | 3.15     |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | -1.65    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8965     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 104      |
# |    ep_rew_mean     | -61.2    |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 72       |
# |    time_elapsed    | 200      |
# |    total_timesteps | 14621    |
# | train/             |          |
# |    actor_loss      | 0.598    |
# |    critic_loss     | 12.2     |
# |    ent_coef        | 0.0945   |
# |    ent_coef_loss   | -0.65    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9620     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | -60.5    |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 71       |
# |    time_elapsed    | 210      |
# |    total_timesteps | 15080    |
# | train/             |          |
# |    actor_loss      | 3.32     |
# |    critic_loss     | 40.4     |
# |    ent_coef        | 0.09     |
# |    ent_coef_loss   | -0.933   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10079    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | -60      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 70       |
# |    time_elapsed    | 222      |
# |    total_timesteps | 15681    |
# | train/             |          |
# |    actor_loss      | 1.08     |
# |    critic_loss     | 13.5     |
# |    ent_coef        | 0.0871   |
# |    ent_coef_loss   | -0.0366  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10680    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 125      |
# |    ep_rew_mean     | -46.7    |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 65       |
# |    time_elapsed    | 273      |
# |    total_timesteps | 17861    |
# | train/             |          |
# |    actor_loss      | -6.81    |
# |    critic_loss     | 6.05     |
# |    ent_coef        | 0.0798   |
# |    ent_coef_loss   | -0.402   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12860    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 157      |
# |    ep_rew_mean     | -16.4    |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 61       |
# |    time_elapsed    | 350      |
# |    total_timesteps | 21476    |
# | train/             |          |
# |    actor_loss      | -18.2    |
# |    critic_loss     | 3.77     |
# |    ent_coef        | 0.0826   |
# |    ent_coef_loss   | -0.374   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16475    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 203      |
# |    ep_rew_mean     | 25.4     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 57       |
# |    time_elapsed    | 453      |
# |    total_timesteps | 26276    |
# | train/             |          |
# |    actor_loss      | -30.6    |
# |    critic_loss     | 29.3     |
# |    ent_coef        | 0.0637   |
# |    ent_coef_loss   | -0.0572  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21275    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 237      |
# |    ep_rew_mean     | 51.5     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 56       |
# |    time_elapsed    | 528      |
# |    total_timesteps | 29889    |
# | train/             |          |
# |    actor_loss      | -42.4    |
# |    critic_loss     | 21.3     |
# |    ent_coef        | 0.0732   |
# |    ent_coef_loss   | -0.301   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24888    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 282      |
# |    ep_rew_mean     | 84       |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 56       |
# |    time_elapsed    | 613      |
# |    total_timesteps | 34689    |
# | train/             |          |
# |    actor_loss      | -55      |
# |    critic_loss     | 10.8     |
# |    ent_coef        | 0.0871   |
# |    ent_coef_loss   | -0.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29688    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 325      |
# |    ep_rew_mean     | 120      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 57       |
# |    time_elapsed    | 684      |
# |    total_timesteps | 39489    |
# | train/             |          |
# |    actor_loss      | -56.4    |
# |    critic_loss     | 1.39     |
# |    ent_coef        | 0.0549   |
# |    ent_coef_loss   | 0.549    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 34488    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 369      |
# |    ep_rew_mean     | 159      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 57       |
# |    time_elapsed    | 766      |
# |    total_timesteps | 44289    |
# | train/             |          |
# |    actor_loss      | -61.1    |
# |    critic_loss     | 4.28     |
# |    ent_coef        | 0.0444   |
# |    ent_coef_loss   | 1.04     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39288    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | 187      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 58       |
# |    time_elapsed    | 820      |
# |    total_timesteps | 47925    |
# | train/             |          |
# |    actor_loss      | -62.4    |
# |    critic_loss     | 1.17     |
# |    ent_coef        | 0.0438   |
# |    ent_coef_loss   | 0.175    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 42924    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 442      |
# |    ep_rew_mean     | 219      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 59       |
# |    time_elapsed    | 887      |
# |    total_timesteps | 52579    |
# | train/             |          |
# |    actor_loss      | -66.2    |
# |    critic_loss     | 0.736    |
# |    ent_coef        | 0.0514   |
# |    ent_coef_loss   | 1.55     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47578    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 485      |
# |    ep_rew_mean     | 256      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 60       |
# |    time_elapsed    | 955      |
# |    total_timesteps | 57379    |
# | train/             |          |
# |    actor_loss      | -70.8    |
# |    critic_loss     | 2.25     |
# |    ent_coef        | 0.0497   |
# |    ent_coef_loss   | -1.11    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 52378    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 529      |
# |    ep_rew_mean     | 288      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 60       |
# |    time_elapsed    | 1029     |
# |    total_timesteps | 62179    |
# | train/             |          |
# |    actor_loss      | -74.1    |
# |    critic_loss     | 0.721    |
# |    ent_coef        | 0.0428   |
# |    ent_coef_loss   | -0.513   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 57178    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 574      |
# |    ep_rew_mean     | 329      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 60       |
# |    time_elapsed    | 1098     |
# |    total_timesteps | 66979    |
# | train/             |          |
# |    actor_loss      | -69.8    |
# |    critic_loss     | 1.57     |
# |    ent_coef        | 0.0347   |
# |    ent_coef_loss   | 0.79     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 61978    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 619      |
# |    ep_rew_mean     | 373      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 61       |
# |    time_elapsed    | 1167     |
# |    total_timesteps | 71779    |
# | train/             |          |
# |    actor_loss      | -73.8    |
# |    critic_loss     | 2.91     |
# |    ent_coef        | 0.0352   |
# |    ent_coef_loss   | -0.11    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 66778    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 663      |
# |    ep_rew_mean     | 416      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 61       |
# |    time_elapsed    | 1238     |
# |    total_timesteps | 76579    |
# | train/             |          |
# |    actor_loss      | -75.1    |
# |    critic_loss     | 2.37     |
# |    ent_coef        | 0.0337   |
# |    ent_coef_loss   | -0.263   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 71578    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 707      |
# |    ep_rew_mean     | 459      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 62       |
# |    time_elapsed    | 1308     |
# |    total_timesteps | 81379    |
# | train/             |          |
# |    actor_loss      | -76.5    |
# |    critic_loss     | 0.974    |
# |    ent_coef        | 0.0342   |
# |    ent_coef_loss   | 0.145    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 76378    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 751      |
# |    ep_rew_mean     | 502      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 62       |
# |    time_elapsed    | 1378     |
# |    total_timesteps | 86179    |
# | train/             |          |
# |    actor_loss      | -79.6    |
# |    critic_loss     | 2.71     |
# |    ent_coef        | 0.032    |
# |    ent_coef_loss   | -0.95    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 81178    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 792      |
# |    ep_rew_mean     | 545      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 62       |
# |    time_elapsed    | 1450     |
# |    total_timesteps | 90979    |
# | train/             |          |
# |    actor_loss      | -79.9    |
# |    critic_loss     | 1.41     |
# |    ent_coef        | 0.0257   |
# |    ent_coef_loss   | -0.961   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 85978    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 835      |
# |    ep_rew_mean     | 582      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 63       |
# |    time_elapsed    | 1519     |
# |    total_timesteps | 95779    |
# | train/             |          |
# |    actor_loss      | -80.1    |
# |    critic_loss     | 1.18     |
# |    ent_coef        | 0.0231   |
# |    ent_coef_loss   | -0.426   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 90778    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 880      |
# |    ep_rew_mean     | 625      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 63       |
# |    time_elapsed    | 1588     |
# |    total_timesteps | 100579   |
# | train/             |          |
# |    actor_loss      | -80.3    |
# |    critic_loss     | 0.846    |
# |    ent_coef        | 0.0233   |
# |    ent_coef_loss   | 0.564    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 95578    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 912      |
# |    ep_rew_mean     | 658      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 63       |
# |    time_elapsed    | 1641     |
# |    total_timesteps | 104196   |
# | train/             |          |
# |    actor_loss      | -80.7    |
# |    critic_loss     | 1.88     |
# |    ent_coef        | 0.0249   |
# |    ent_coef_loss   | -0.457   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99195    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 942      |
# |    ep_rew_mean     | 690      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 63       |
# |    time_elapsed    | 1693     |
# |    total_timesteps | 107832   |
# | train/             |          |
# |    actor_loss      | -78.5    |
# |    critic_loss     | 0.617    |
# |    ent_coef        | 0.0251   |
# |    ent_coef_loss   | 0.484    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102831   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 987      |
# |    ep_rew_mean     | 733      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 63       |
# |    time_elapsed    | 1763     |
# |    total_timesteps | 112632   |
# | train/             |          |
# |    actor_loss      | -79      |
# |    critic_loss     | 0.681    |
# |    ent_coef        | 0.0279   |
# |    ent_coef_loss   | -0.182   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 107631   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | 772      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 64       |
# |    time_elapsed    | 1832     |
# |    total_timesteps | 117432   |
# | train/             |          |
# |    actor_loss      | -82.6    |
# |    critic_loss     | 0.405    |
# |    ent_coef        | 0.027    |
# |    ent_coef_loss   | -1.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 112431   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | 801      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 64       |
# |    time_elapsed    | 1887     |
# |    total_timesteps | 121270   |
# | train/             |          |
# |    actor_loss      | -82.7    |
# |    critic_loss     | 0.969    |
# |    ent_coef        | 0.0261   |
# |    ent_coef_loss   | 0.393    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 116269   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 840      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 64       |
# |    time_elapsed    | 1954     |
# |    total_timesteps | 126070   |
# | train/             |          |
# |    actor_loss      | -82.5    |
# |    critic_loss     | 1.5      |
# |    ent_coef        | 0.0222   |
# |    ent_coef_loss   | 0.351    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 121069   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 856      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 64       |
# |    time_elapsed    | 2006     |
# |    total_timesteps | 129730   |
# | train/             |          |
# |    actor_loss      | -79.2    |
# |    critic_loss     | 0.654    |
# |    ent_coef        | 0.0192   |
# |    ent_coef_loss   | 0.178    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 124729   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 866      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 64       |
# |    time_elapsed    | 2074     |
# |    total_timesteps | 134530   |
# | train/             |          |
# |    actor_loss      | -81      |
# |    critic_loss     | 0.792    |
# |    ent_coef        | 0.0214   |
# |    ent_coef_loss   | 1.28     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 129529   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 854      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 64       |
# |    time_elapsed    | 2127     |
# |    total_timesteps | 138190   |
# | train/             |          |
# |    actor_loss      | -83.2    |
# |    critic_loss     | 0.487    |
# |    ent_coef        | 0.0208   |
# |    ent_coef_loss   | -0.183   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 133189   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 870      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 65       |
# |    time_elapsed    | 2194     |
# |    total_timesteps | 142990   |
# | train/             |          |
# |    actor_loss      | -84.3    |
# |    critic_loss     | 0.299    |
# |    ent_coef        | 0.0236   |
# |    ent_coef_loss   | -0.329   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 137989   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 869      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 65       |
# |    time_elapsed    | 2247     |
# |    total_timesteps | 146683   |
# | train/             |          |
# |    actor_loss      | -82.2    |
# |    critic_loss     | 0.482    |
# |    ent_coef        | 0.0226   |
# |    ent_coef_loss   | 0.347    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 141682   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 864      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 65       |
# |    time_elapsed    | 2298     |
# |    total_timesteps | 150335   |
# | train/             |          |
# |    actor_loss      | -83      |
# |    critic_loss     | 0.38     |
# |    ent_coef        | 0.0216   |
# |    ent_coef_loss   | 0.464    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 145334   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 857      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 65       |
# |    time_elapsed    | 2351     |
# |    total_timesteps | 154033   |
# | train/             |          |
# |    actor_loss      | -81.5    |
# |    critic_loss     | 1.12     |
# |    ent_coef        | 0.0207   |
# |    ent_coef_loss   | -0.28    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 149032   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 863      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 65       |
# |    time_elapsed    | 2410     |
# |    total_timesteps | 157945   |
# | train/             |          |
# |    actor_loss      | -83.8    |
# |    critic_loss     | 0.276    |
# |    ent_coef        | 0.0237   |
# |    ent_coef_loss   | 0.512    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 152944   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 875      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 65       |
# |    time_elapsed    | 2479     |
# |    total_timesteps | 162745   |
# | train/             |          |
# |    actor_loss      | -81.6    |
# |    critic_loss     | 3.2      |
# |    ent_coef        | 0.022    |
# |    ent_coef_loss   | 0.755    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 157744   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | 872      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 65       |
# |    time_elapsed    | 2533     |
# |    total_timesteps | 166441   |
# | train/             |          |
# |    actor_loss      | -84      |
# |    critic_loss     | 0.654    |
# |    ent_coef        | 0.0205   |
# |    ent_coef_loss   | 0.241    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 161440   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | 883      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 65       |
# |    time_elapsed    | 2603     |
# |    total_timesteps | 171241   |
# | train/             |          |
# |    actor_loss      | -86.9    |
# |    critic_loss     | 0.239    |
# |    ent_coef        | 0.0198   |
# |    ent_coef_loss   | -1.63    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 166240   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | 876      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 65       |
# |    time_elapsed    | 2658     |
# |    total_timesteps | 174970   |
# | train/             |          |
# |    actor_loss      | -83.4    |
# |    critic_loss     | 2.82     |
# |    ent_coef        | 0.0185   |
# |    ent_coef_loss   | 0.133    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 169969   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.07e+03 |
# |    ep_rew_mean     | 865      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 65       |
# |    time_elapsed    | 2712     |
# |    total_timesteps | 178701   |
# | train/             |          |
# |    actor_loss      | -85.6    |
# |    critic_loss     | 0.499    |
# |    ent_coef        | 0.0179   |
# |    ent_coef_loss   | 0.716    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 173700   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.07e+03 |
# |    ep_rew_mean     | 865      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 65       |
# |    time_elapsed    | 2781     |
# |    total_timesteps | 183501   |
# | train/             |          |
# |    actor_loss      | -84      |
# |    critic_loss     | 2        |
# |    ent_coef        | 0.0178   |
# |    ent_coef_loss   | -0.706   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 178500   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | 855      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 66       |
# |    time_elapsed    | 2838     |
# |    total_timesteps | 187373   |
# | train/             |          |
# |    actor_loss      | -84.6    |
# |    critic_loss     | 0.372    |
# |    ent_coef        | 0.0158   |
# |    ent_coef_loss   | 1.12     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 182372   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | 857      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 66       |
# |    time_elapsed    | 2908     |
# |    total_timesteps | 192173   |
# | train/             |          |
# |    actor_loss      | -87.3    |
# |    critic_loss     | 0.253    |
# |    ent_coef        | 0.0147   |
# |    ent_coef_loss   | 0.388    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 187172   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.05e+03 |
# |    ep_rew_mean     | 845      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 66       |
# |    time_elapsed    | 2961     |
# |    total_timesteps | 195833   |
# | train/             |          |
# |    actor_loss      | -84.3    |
# |    critic_loss     | 1.56     |
# |    ent_coef        | 0.017    |
# |    ent_coef_loss   | 1.62     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 190832   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 839      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 66       |
# |    time_elapsed    | 3013     |
# |    total_timesteps | 199561   |
# | train/             |          |
# |    actor_loss      | -86      |
# |    critic_loss     | 0.908    |
# |    ent_coef        | 0.0142   |
# |    ent_coef_loss   | 0.346    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 194560   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 841      |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 66       |
# |    time_elapsed    | 3081     |
# |    total_timesteps | 204361   |
# | train/             |          |
# |    actor_loss      | -85.9    |
# |    critic_loss     | 0.2      |
# |    ent_coef        | 0.0124   |
# |    ent_coef_loss   | 1.8      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 199360   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | 830      |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 66       |
# |    time_elapsed    | 3115     |
# |    total_timesteps | 206797   |
# | train/             |          |
# |    actor_loss      | -88.2    |
# |    critic_loss     | 0.19     |
# |    ent_coef        | 0.0139   |
# |    ent_coef_loss   | -0.0147  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 201796   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 838      |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 66       |
# |    time_elapsed    | 3184     |
# |    total_timesteps | 211597   |
# | train/             |          |
# |    actor_loss      | -89      |
# |    critic_loss     | 0.464    |
# |    ent_coef        | 0.00888  |
# |    ent_coef_loss   | -0.524   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 206596   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 840      |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 66       |
# |    time_elapsed    | 3253     |
# |    total_timesteps | 216397   |
# | train/             |          |
# |    actor_loss      | -88.9    |
# |    critic_loss     | 0.0909   |
# |    ent_coef        | 0.00906  |
# |    ent_coef_loss   | 0.76     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 211396   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 837      |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 66       |
# |    time_elapsed    | 3320     |
# |    total_timesteps | 221197   |
# | train/             |          |
# |    actor_loss      | -88.2    |
# |    critic_loss     | 0.156    |
# |    ent_coef        | 0.00911  |
# |    ent_coef_loss   | -0.565   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 216196   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.05e+03 |
# |    ep_rew_mean     | 844      |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 66       |
# |    time_elapsed    | 3389     |
# |    total_timesteps | 225997   |
# | train/             |          |
# |    actor_loss      | -87.7    |
# |    critic_loss     | 0.148    |
# |    ent_coef        | 0.0121   |
# |    ent_coef_loss   | 0.292    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 220996   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.05e+03 |
# |    ep_rew_mean     | 836      |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 66       |
# |    time_elapsed    | 3457     |
# |    total_timesteps | 230797   |
# | train/             |          |
# |    actor_loss      | -87.7    |
# |    critic_loss     | 0.0633   |
# |    ent_coef        | 0.0116   |
# |    ent_coef_loss   | -0.978   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 225796   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | 847      |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 66       |
# |    time_elapsed    | 3525     |
# |    total_timesteps | 235597   |
# | train/             |          |
# |    actor_loss      | -86.9    |
# |    critic_loss     | 0.117    |
# |    ent_coef        | 0.0133   |
# |    ent_coef_loss   | 0.08     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 230596   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | 851      |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 66       |
# |    time_elapsed    | 3594     |
# |    total_timesteps | 240397   |
# | train/             |          |
# |    actor_loss      | -87.4    |
# |    critic_loss     | 0.147    |
# |    ent_coef        | 0.0132   |
# |    ent_coef_loss   | 1.08     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 235396   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.07e+03 |
# |    ep_rew_mean     | 867      |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 66       |
# |    time_elapsed    | 3663     |
# |    total_timesteps | 245197   |
# | train/             |          |
# |    actor_loss      | -88      |
# |    critic_loss     | 0.081    |
# |    ent_coef        | 0.0156   |
# |    ent_coef_loss   | 0.529    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 240196   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.07e+03 |
# |    ep_rew_mean     | 872      |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 66       |
# |    time_elapsed    | 3733     |
# |    total_timesteps | 249997   |
# | train/             |          |
# |    actor_loss      | -90.1    |
# |    critic_loss     | 0.268    |
# |    ent_coef        | 0.015    |
# |    ent_coef_loss   | -0.228   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 244996   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | 886      |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 67       |
# |    time_elapsed    | 3801     |
# |    total_timesteps | 254797   |
# | train/             |          |
# |    actor_loss      | -91.1    |
# |    critic_loss     | 8.81     |
# |    ent_coef        | 0.0131   |
# |    ent_coef_loss   | -0.712   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 249796   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | 902      |
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 67       |
# |    time_elapsed    | 3871     |
# |    total_timesteps | 259597   |
# | train/             |          |
# |    actor_loss      | -92.3    |
# |    critic_loss     | 0.0572   |
# |    ent_coef        | 0.0132   |
# |    ent_coef_loss   | 0.0969   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 254596   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | 904      |
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 67       |
# |    time_elapsed    | 3921     |
# |    total_timesteps | 263242   |
# | train/             |          |
# |    actor_loss      | -91.8    |
# |    critic_loss     | 0.117    |
# |    ent_coef        | 0.0131   |
# |    ent_coef_loss   | 0.665    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 258241   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 917      |
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 67       |
# |    time_elapsed    | 3989     |
# |    total_timesteps | 268042   |
# | train/             |          |
# |    actor_loss      | -92.9    |
# |    critic_loss     | 0.0997   |
# |    ent_coef        | 0.0122   |
# |    ent_coef_loss   | -0.661   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 263041   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 919      |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 67       |
# |    time_elapsed    | 4057     |
# |    total_timesteps | 272842   |
# | train/             |          |
# |    actor_loss      | -92.7    |
# |    critic_loss     | 0.0781   |
# |    ent_coef        | 0.0118   |
# |    ent_coef_loss   | -1.09    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 267841   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 931      |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 67       |
# |    time_elapsed    | 4125     |
# |    total_timesteps | 277642   |
# | train/             |          |
# |    actor_loss      | -93.9    |
# |    critic_loss     | 0.0445   |
# |    ent_coef        | 0.0125   |
# |    ent_coef_loss   | 1.27     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 272641   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 932      |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 67       |
# |    time_elapsed    | 4193     |
# |    total_timesteps | 282442   |
# | train/             |          |
# |    actor_loss      | -93.6    |
# |    critic_loss     | 0.307    |
# |    ent_coef        | 0.0109   |
# |    ent_coef_loss   | 1.57     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 277441   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 932      |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 67       |
# |    time_elapsed    | 4245     |
# |    total_timesteps | 286122   |
# | train/             |          |
# |    actor_loss      | -94.1    |
# |    critic_loss     | 0.0504   |
# |    ent_coef        | 0.0093   |
# |    ent_coef_loss   | 0.143    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 281121   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 919      |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 67       |
# |    time_elapsed    | 4280     |
# |    total_timesteps | 288638   |
# | train/             |          |
# |    actor_loss      | -93.2    |
# |    critic_loss     | 0.0495   |
# |    ent_coef        | 0.0114   |
# |    ent_coef_loss   | -2.37    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 283637   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 921      |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 67       |
# |    time_elapsed    | 4348     |
# |    total_timesteps | 293438   |
# | train/             |          |
# |    actor_loss      | -93.7    |
# |    critic_loss     | 0.265    |
# |    ent_coef        | 0.0128   |
# |    ent_coef_loss   | -2.09    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 288437   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 932      |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 67       |
# |    time_elapsed    | 4416     |
# |    total_timesteps | 298238   |
# | train/             |          |
# |    actor_loss      | -94.4    |
# |    critic_loss     | 0.151    |
# |    ent_coef        | 0.0178   |
# |    ent_coef_loss   | -0.453   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 293237   |
# ---------------------------------

# %%
model.save("sac_ballplate")

# %%
model = SAC.load("sac_ballplate", env=env)

# %%
mean_reward, std_reward = evaluate_policy(
    model,
    env,
    n_eval_episodes=20,
    deterministic=True,
    return_episode_rewards=False
)

print("===== Evaluation Summary =====")
print(f"Mean Episode Reward : {mean_reward:.2f}")
print(f"Std Episode Reward  : {std_reward:.2f}")
# Out:
# ===== Evaluation Summary =====
# Mean Episode Reward : 920.37
# Std Episode Reward  : 250.72

# %%
episode_rewards, episode_lengths = evaluate_policy(
    model,
    env,
    n_eval_episodes=10,
    deterministic=True,
    return_episode_rewards=True
)

print("===== Episode-wise Metrics =====")
for i, (r, l) in enumerate(zip(episode_rewards, episode_lengths), 1):
    print(f"Episode {i:02d} | Reward: {r:.2f} | Length: {l}")
# Out:
# ===== Episode-wise Metrics =====
# Episode 01 | Reward: 890.89 | Length: 1200
# Episode 02 | Reward: 909.31 | Length: 1200
# Episode 03 | Reward: 937.20 | Length: 1200
# Episode 04 | Reward: 901.12 | Length: 1200
# Episode 05 | Reward: 945.92 | Length: 1200
# Episode 06 | Reward: 958.98 | Length: 1200
# Episode 07 | Reward: 903.08 | Length: 1200
# Episode 08 | Reward: 928.41 | Length: 1200
# Episode 09 | Reward: 931.17 | Length: 1200
# Episode 10 | Reward: 908.96 | Length: 1200

# %% [markdown]
# last cell for demo

# %%
eval_env = env = gym.make("BallPlate-v0", render_mode="human")

episodes = 5
for ep in range(episodes):
    obs, _ = eval_env.reset()
    done = False
    total_reward = 0.0
    steps = 0

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, truncated, _ = eval_env.step(action)

        total_reward += reward
        steps += 1

        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                done = True

    print(f"[Render Eval] Episode {ep+1} | Total Reward: {total_reward:.2f} | Steps: {steps}")

eval_env.close()
# Out:
# [Render Eval] Episode 1 | Total Reward: 3878.65 | Steps: 5185
