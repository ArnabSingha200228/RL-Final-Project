# %% [markdown]
# *New FetchReach-v4 — PPO (Robotic Manipulation Benchmark)*

# %% [markdown]
# CELL 0- Module Install and Verify

# %%
# !python -m pip install --upgrade pip setuptools wheel
# !pip install --upgrade certifi

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121 --no-cache-dir

# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Torch version: 2.5.1+cu121
# CUDA available: True

# %%
# !pip install gymnasium gymnasium-robotics stable-baselines3 numpy matplotlib

# %%
import gymnasium as gym
import gymnasium_robotics

env = gym.make("FetchReach-v4")
print("FetchReach OK")
# Out:
# FetchReach OK

# %%
# !pip install gymnasium gymnasium-robotics stable-baselines3 numpy matplotlib torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ERROR: Could not find a version that satisfies the requirement gymnasium (from versions: none)
# ERROR: No matching distribution found for gymnasium

# %%
import gymnasium as gym
import gymnasium_robotics
import torch
from stable_baselines3 import PPO
import numpy as np
import matplotlib.pyplot as plt

print("All modules installed correctly")
print("CUDA available:", torch.cuda.is_available())
# Out:
# All modules installed correctly
# CUDA available: True

# %%
import sys
print(sys.version)
# Out:
# 3.11.0 (main, Oct 24 2022, 18:26:48) [MSC v.1933 64 bit (AMD64)]

# %% [markdown]
# 🔵 CELL 1 — Imports & Setup

# %%
import gymnasium as gym
import gymnasium_robotics
import numpy as np
import matplotlib.pyplot as plt
import time

from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.env_util import make_vec_env

# %% [markdown]
# 🔵 CELL 2 — Environment Creation (Monitored)
#
# We wrap the environment with Monitor to log rewards, episode lengths, etc.

# %%
def make_env():
    env = gym.make("FetchReach-v4")
    env = Monitor(env)
    return env

env = make_vec_env(make_env, n_envs=1)

# %% [markdown]
# 🔵 CELL 3 — PPO  Model Configuration
#
# These hyperparameters are reasonable, stable, and report-safe.

# %%
model = PPO(
    policy="MultiInputPolicy",
    env=env,

    learning_rate=1e-4,
    n_steps=1024,
    batch_size=256,
    gamma=0.98,

    clip_range=0.2,
    ent_coef=0.01,
    verbose=1,
)

# TOTAL_TIMESTEPS = 300_000
# Out:
# Using cuda device

# %% [markdown]
# 🔵 CELL 4 — Training

# %%
TOTAL_TIMESTEPS = 300_000

model.learn(total_timesteps=TOTAL_TIMESTEPS)
model.save("ppo_fetchreach")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -49.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 197      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1024     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.9        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 208          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0041457294 |
# |    clip_fraction        | 0.00508      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.68        |
# |    explained_variance   | 0.00369      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 52.3         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00282     |
# |    std                  | 1            |
# |    value_loss           | 115          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.5        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 210          |
# |    iterations           | 3            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0015112942 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.68        |
# |    explained_variance   | 0.0072       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 52.5         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00109     |
# |    std                  | 1            |
# |    value_loss           | 111          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 212         |
# |    iterations           | 4           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.001460253 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | 0.00417     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 47.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00109    |
# |    std                  | 1           |
# |    value_loss           | 104         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.2       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 5           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.004537167 |
# |    clip_fraction        | 0.00771     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | 0.00624     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 44.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00328    |
# |    std                  | 1           |
# |    value_loss           | 103         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.2        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 235          |
# |    iterations           | 6            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0021358123 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.68        |
# |    explained_variance   | 0.000106     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 47           |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00139     |
# |    std                  | 1            |
# |    value_loss           | 96.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.1        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 244          |
# |    iterations           | 7            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0012689579 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.69        |
# |    explained_variance   | 0.00271      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 48.1         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.001       |
# |    std                  | 1            |
# |    value_loss           | 97.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.4        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 250          |
# |    iterations           | 8            |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0023929258 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.69        |
# |    explained_variance   | 0.00608      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 44.7         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00168     |
# |    std                  | 1            |
# |    value_loss           | 93.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 9           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.004882302 |
# |    clip_fraction        | 0.00811     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.69       |
# |    explained_variance   | 0.0121      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 45.1        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00401    |
# |    std                  | 1           |
# |    value_loss           | 92.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.6        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 10           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0031274525 |
# |    clip_fraction        | 0.00283      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.69        |
# |    explained_variance   | 0.0151       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 42.2         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00199     |
# |    std                  | 1            |
# |    value_loss           | 90.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.7        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 260          |
# |    iterations           | 11           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 0.0025452524 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.69        |
# |    explained_variance   | 0.0226       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 43.2         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0016      |
# |    std                  | 1            |
# |    value_loss           | 87.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.7        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 263          |
# |    iterations           | 12           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0024536117 |
# |    clip_fraction        | 0.000586     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.69        |
# |    explained_variance   | 0.0206       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 39.8         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00166     |
# |    std                  | 1            |
# |    value_loss           | 86.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.6        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 264          |
# |    iterations           | 13           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0038377342 |
# |    clip_fraction        | 0.00352      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.69        |
# |    explained_variance   | 0.0199       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 39           |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0026      |
# |    std                  | 1            |
# |    value_loss           | 82.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.6        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 263          |
# |    iterations           | 14           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0045623775 |
# |    clip_fraction        | 0.00566      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.69        |
# |    explained_variance   | 0.0336       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 40.1         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00348     |
# |    std                  | 1            |
# |    value_loss           | 82.2         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 50            |
# |    ep_rew_mean          | -49.6         |
# |    success_rate         | 0             |
# | time/                   |               |
# |    fps                  | 266           |
# |    iterations           | 15            |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 15360         |
# | train/                  |               |
# |    approx_kl            | 0.00031029363 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.69         |
# |    explained_variance   | 0.0281        |
# |    learning_rate        | 0.0001        |
# |    loss                 | 38.7          |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000167     |
# |    std                  | 1             |
# |    value_loss           | 81.2          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 268         |
# |    iterations           | 16          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.003948248 |
# |    clip_fraction        | 0.0041      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.69       |
# |    explained_variance   | 0.0307      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 37.5        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00283    |
# |    std                  | 1           |
# |    value_loss           | 78.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.6        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 270          |
# |    iterations           | 17           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0035829209 |
# |    clip_fraction        | 0.00264      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.69        |
# |    explained_variance   | 0.0381       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 37.2         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00266     |
# |    std                  | 1            |
# |    value_loss           | 78.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.7        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 272          |
# |    iterations           | 18           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0022477922 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.69        |
# |    explained_variance   | 0.0252       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 38.9         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00153     |
# |    std                  | 1            |
# |    value_loss           | 76.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 272         |
# |    iterations           | 19          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.003052646 |
# |    clip_fraction        | 0.00146     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.69       |
# |    explained_variance   | 0.0257      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 36.7        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00211    |
# |    std                  | 1           |
# |    value_loss           | 76          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.4        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 273          |
# |    iterations           | 20           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0060281283 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.69        |
# |    explained_variance   | 0.0297       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 34.9         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00424     |
# |    std                  | 1            |
# |    value_loss           | 71.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.5        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 274          |
# |    iterations           | 21           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 21504        |
# | train/                  |              |
# |    approx_kl            | 0.0048523946 |
# |    clip_fraction        | 0.00771      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.7         |
# |    explained_variance   | 0.0267       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 33           |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00345     |
# |    std                  | 1.01         |
# |    value_loss           | 71.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 273         |
# |    iterations           | 22          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005798756 |
# |    clip_fraction        | 0.0121      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.7        |
# |    explained_variance   | 0.028       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 34          |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00405    |
# |    std                  | 1.01        |
# |    value_loss           | 72.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.4        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 272          |
# |    iterations           | 23           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0015264844 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.7         |
# |    explained_variance   | 0.0215       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 36.8         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000855    |
# |    std                  | 1.01         |
# |    value_loss           | 71.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.6        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 270          |
# |    iterations           | 24           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0025563845 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.7         |
# |    explained_variance   | 0.0204       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 33.7         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00196     |
# |    std                  | 1.01         |
# |    value_loss           | 69.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.6        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 269          |
# |    iterations           | 25           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0026642773 |
# |    clip_fraction        | 0.00137      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.7         |
# |    explained_variance   | 0.0196       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 32.1         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00153     |
# |    std                  | 1.01         |
# |    value_loss           | 68.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 26          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.002989133 |
# |    clip_fraction        | 0.00156     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.7        |
# |    explained_variance   | 0.0258      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 33.7        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00193    |
# |    std                  | 1.01        |
# |    value_loss           | 67.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -49.4      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 268        |
# |    iterations           | 27         |
# |    time_elapsed         | 102        |
# |    total_timesteps      | 27648      |
# | train/                  |            |
# |    approx_kl            | 0.00846681 |
# |    clip_fraction        | 0.0362     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.7       |
# |    explained_variance   | 0.0152     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 32.9       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.00639   |
# |    std                  | 1.01       |
# |    value_loss           | 65.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 267         |
# |    iterations           | 28          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007185651 |
# |    clip_fraction        | 0.0229      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.7        |
# |    explained_variance   | 0.0242      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 30.5        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00525    |
# |    std                  | 1.01        |
# |    value_loss           | 64          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.4        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 29           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0013988528 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.69        |
# |    explained_variance   | 0.0177       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 31.2         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.001       |
# |    std                  | 1            |
# |    value_loss           | 64.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.5        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 269          |
# |    iterations           | 30           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0054895207 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.7         |
# |    explained_variance   | 0.0136       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 30.8         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00432     |
# |    std                  | 1.01         |
# |    value_loss           | 64           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 31          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.003970532 |
# |    clip_fraction        | 0.0042      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.7        |
# |    explained_variance   | 0.0107      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 29.9        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00303    |
# |    std                  | 1.01        |
# |    value_loss           | 62.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.7        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 271          |
# |    iterations           | 32           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0069190883 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.71        |
# |    explained_variance   | 0.00822      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 29.8         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00592     |
# |    std                  | 1.01         |
# |    value_loss           | 61.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.5        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 271          |
# |    iterations           | 33           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 33792        |
# | train/                  |              |
# |    approx_kl            | 0.0025971993 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.71        |
# |    explained_variance   | 0.0116       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 30.2         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00212     |
# |    std                  | 1.01         |
# |    value_loss           | 60.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.5        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 272          |
# |    iterations           | 34           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0031468554 |
# |    clip_fraction        | 0.00205      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.71        |
# |    explained_variance   | 0.00396      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 29.9         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00211     |
# |    std                  | 1.01         |
# |    value_loss           | 57.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 272         |
# |    iterations           | 35          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.004584986 |
# |    clip_fraction        | 0.00723     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.71       |
# |    explained_variance   | 0.00453     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 29          |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0039     |
# |    std                  | 1.01        |
# |    value_loss           | 58          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.5        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 272          |
# |    iterations           | 36           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0020250266 |
# |    clip_fraction        | 0.000586     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.71        |
# |    explained_variance   | 0.00283      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 26.6         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00187     |
# |    std                  | 1.01         |
# |    value_loss           | 57.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.4        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 273          |
# |    iterations           | 37           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 37888        |
# | train/                  |              |
# |    approx_kl            | 0.0012819925 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.72        |
# |    explained_variance   | 0.00318      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 28           |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00103     |
# |    std                  | 1.01         |
# |    value_loss           | 57.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.5        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 274          |
# |    iterations           | 38           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0006186743 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.72        |
# |    explained_variance   | 0.00269      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 26.9         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000496    |
# |    std                  | 1.01         |
# |    value_loss           | 54.4         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 50            |
# |    ep_rew_mean          | -49.5         |
# |    success_rate         | 0             |
# | time/                   |               |
# |    fps                  | 275           |
# |    iterations           | 39            |
# |    time_elapsed         | 145           |
# |    total_timesteps      | 39936         |
# | train/                  |               |
# |    approx_kl            | 0.00083902763 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.72         |
# |    explained_variance   | 0.00405       |
# |    learning_rate        | 0.0001        |
# |    loss                 | 27            |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000622     |
# |    std                  | 1.01          |
# |    value_loss           | 54.2          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.5        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 40           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0027480004 |
# |    clip_fraction        | 0.00117      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.72        |
# |    explained_variance   | 0.00782      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 25.3         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00228     |
# |    std                  | 1.01         |
# |    value_loss           | 53.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.5        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 276          |
# |    iterations           | 41           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 41984        |
# | train/                  |              |
# |    approx_kl            | 0.0010050836 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.73        |
# |    explained_variance   | 0.0056       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 26.7         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000962    |
# |    std                  | 1.01         |
# |    value_loss           | 53           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 42          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.003565525 |
# |    clip_fraction        | 0.00215     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | 0.00528     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 24.9        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00279    |
# |    std                  | 1.01        |
# |    value_loss           | 52          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 43          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.002675603 |
# |    clip_fraction        | 0.00127     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | 0.00301     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 24.1        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00197    |
# |    std                  | 1.01        |
# |    value_loss           | 49.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.4        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 44           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0022624952 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.73        |
# |    explained_variance   | 0.00192      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 22.8         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00179     |
# |    std                  | 1.01         |
# |    value_loss           | 49.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.4        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 276          |
# |    iterations           | 45           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0011062073 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.73        |
# |    explained_variance   | 0.00298      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 24.5         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000746    |
# |    std                  | 1.01         |
# |    value_loss           | 50           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.4        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 277          |
# |    iterations           | 46           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0020339366 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.73        |
# |    explained_variance   | 0.000664     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 24           |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00155     |
# |    std                  | 1.01         |
# |    value_loss           | 48.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.6        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 277          |
# |    iterations           | 47           |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 48128        |
# | train/                  |              |
# |    approx_kl            | 0.0028705809 |
# |    clip_fraction        | 0.00146      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.73        |
# |    explained_variance   | 0.00194      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 24.1         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00222     |
# |    std                  | 1.01         |
# |    value_loss           | 48.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.5        |
# |    success_rate         | 0.01         |
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 48           |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0049534123 |
# |    clip_fraction        | 0.00801      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.73        |
# |    explained_variance   | 0.00247      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 22.2         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00394     |
# |    std                  | 1.01         |
# |    value_loss           | 45.3         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 50            |
# |    ep_rew_mean          | -49.5         |
# |    success_rate         | 0.01          |
# | time/                   |               |
# |    fps                  | 278           |
# |    iterations           | 49            |
# |    time_elapsed         | 180           |
# |    total_timesteps      | 50176         |
# | train/                  |               |
# |    approx_kl            | 0.00025842374 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.73         |
# |    explained_variance   | 0.00103       |
# |    learning_rate        | 0.0001        |
# |    loss                 | 22.5          |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -8.38e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 46.5          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.5       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 277         |
# |    iterations           | 50          |
# |    time_elapsed         | 184         |
# ...
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.91       |
# |    explained_variance   | 9.92e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0177     |
# |    n_updates            | 2760        |
# |    policy_gradient_loss | -0.00469    |
# |    std                  | 1.06        |
# |    value_loss           | 0.14        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.1        |
# |    success_rate         | 0.01         |
# | time/                   |              |
# |    fps                  | 288          |
# |    iterations           | 278          |
# |    time_elapsed         | 988          |
# |    total_timesteps      | 284672       |
# | train/                  |              |
# |    approx_kl            | 0.0016700639 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.92        |
# |    explained_variance   | 0.00018      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.49         |
# |    n_updates            | 2770         |
# |    policy_gradient_loss | -0.000582    |
# |    std                  | 1.06         |
# |    value_loss           | 1.12         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49         |
# |    success_rate         | 0.02        |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 279         |
# |    time_elapsed         | 991         |
# |    total_timesteps      | 285696      |
# | train/                  |             |
# |    approx_kl            | 0.009500487 |
# |    clip_fraction        | 0.0526      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.92       |
# |    explained_variance   | -0.000194   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.474       |
# |    n_updates            | 2780        |
# |    policy_gradient_loss | -0.00464    |
# |    std                  | 1.06        |
# |    value_loss           | 0.829       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -49.1      |
# |    success_rate         | 0.02       |
# | time/                   |            |
# |    fps                  | 288        |
# |    iterations           | 280        |
# |    time_elapsed         | 994        |
# |    total_timesteps      | 286720     |
# | train/                  |            |
# |    approx_kl            | 0.01171666 |
# |    clip_fraction        | 0.067      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.92      |
# |    explained_variance   | 7.02e-05   |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.142      |
# |    n_updates            | 2790       |
# |    policy_gradient_loss | -0.0049    |
# |    std                  | 1.06       |
# |    value_loss           | 0.643      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.2       |
# |    success_rate         | 0.02        |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 281         |
# |    time_elapsed         | 998         |
# |    total_timesteps      | 287744      |
# | train/                  |             |
# |    approx_kl            | 0.012719154 |
# |    clip_fraction        | 0.0562      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.92       |
# |    explained_variance   | 0.000132    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0927      |
# |    n_updates            | 2800        |
# |    policy_gradient_loss | -0.00436    |
# |    std                  | 1.06        |
# |    value_loss           | 0.356       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.4        |
# |    success_rate         | 0.02         |
# | time/                   |              |
# |    fps                  | 288          |
# |    iterations           | 282          |
# |    time_elapsed         | 1001         |
# |    total_timesteps      | 288768       |
# | train/                  |              |
# |    approx_kl            | 0.0026661032 |
# |    clip_fraction        | 0.000586     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.92        |
# |    explained_variance   | 5.25e-05     |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0619      |
# |    n_updates            | 2810         |
# |    policy_gradient_loss | -0.000848    |
# |    std                  | 1.06         |
# |    value_loss           | 0.0184       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.4       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 283         |
# |    time_elapsed         | 1005        |
# |    total_timesteps      | 289792      |
# | train/                  |             |
# |    approx_kl            | 0.008259882 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.92       |
# |    explained_variance   | 0.000145    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0558      |
# |    n_updates            | 2820        |
# |    policy_gradient_loss | -0.00484    |
# |    std                  | 1.06        |
# |    value_loss           | 0.388       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.6       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 284         |
# |    time_elapsed         | 1008        |
# |    total_timesteps      | 290816      |
# | train/                  |             |
# |    approx_kl            | 0.006616503 |
# |    clip_fraction        | 0.0162      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.93       |
# |    explained_variance   | 0.000112    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0204     |
# |    n_updates            | 2830        |
# |    policy_gradient_loss | -0.00228    |
# |    std                  | 1.06        |
# |    value_loss           | 0.0509      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.6       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 285         |
# |    time_elapsed         | 1011        |
# |    total_timesteps      | 291840      |
# | train/                  |             |
# |    approx_kl            | 0.008259484 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.93       |
# |    explained_variance   | 5.96e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0303     |
# |    n_updates            | 2840        |
# |    policy_gradient_loss | -0.00256    |
# |    std                  | 1.07        |
# |    value_loss           | 0.1         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -49.5      |
# |    success_rate         | 0.01       |
# | time/                   |            |
# |    fps                  | 288        |
# |    iterations           | 286        |
# |    time_elapsed         | 1015       |
# |    total_timesteps      | 292864     |
# | train/                  |            |
# |    approx_kl            | 0.00683148 |
# |    clip_fraction        | 0.0355     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.93      |
# |    explained_variance   | -0.000102  |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.00378    |
# |    n_updates            | 2850       |
# |    policy_gradient_loss | -0.00395   |
# |    std                  | 1.06       |
# |    value_loss           | 0.158      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.6        |
# |    success_rate         | 0.01         |
# | time/                   |              |
# |    fps                  | 288          |
# |    iterations           | 287          |
# |    time_elapsed         | 1018         |
# |    total_timesteps      | 293888       |
# | train/                  |              |
# |    approx_kl            | 0.0069754138 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.93        |
# |    explained_variance   | -6.02e-05    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0125       |
# |    n_updates            | 2860         |
# |    policy_gradient_loss | -0.00279     |
# |    std                  | 1.06         |
# |    value_loss           | 0.154        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49.4       |
# |    success_rate         | 0.02        |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 288         |
# |    time_elapsed         | 1021        |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.015234036 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.93       |
# |    explained_variance   | -6.84e-05   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0551     |
# |    n_updates            | 2870        |
# |    policy_gradient_loss | -0.00754    |
# |    std                  | 1.06        |
# |    value_loss           | 0.0719      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -49.1        |
# |    success_rate         | 0.02         |
# | time/                   |              |
# |    fps                  | 288          |
# |    iterations           | 289          |
# |    time_elapsed         | 1025         |
# |    total_timesteps      | 295936       |
# | train/                  |              |
# |    approx_kl            | 0.0036219435 |
# |    clip_fraction        | 0.00254      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.92        |
# |    explained_variance   | 5.91e-05     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.357        |
# |    n_updates            | 2880         |
# |    policy_gradient_loss | -0.000921    |
# |    std                  | 1.06         |
# |    value_loss           | 1.01         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 50            |
# |    ep_rew_mean          | -48.9         |
# |    success_rate         | 0.04          |
# | time/                   |               |
# |    fps                  | 288           |
# |    iterations           | 290           |
# |    time_elapsed         | 1028          |
# |    total_timesteps      | 296960        |
# | train/                  |               |
# |    approx_kl            | 0.00013195252 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.92         |
# |    explained_variance   | 2.88e-05      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.798         |
# |    n_updates            | 2890          |
# |    policy_gradient_loss | 8.5e-05       |
# |    std                  | 1.06          |
# |    value_loss           | 1.38          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49         |
# |    success_rate         | 0.04        |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 291         |
# |    time_elapsed         | 1031        |
# |    total_timesteps      | 297984      |
# | train/                  |             |
# |    approx_kl            | 0.006641916 |
# |    clip_fraction        | 0.0161      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.93       |
# |    explained_variance   | 3.7e-06     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.345       |
# |    n_updates            | 2900        |
# |    policy_gradient_loss | -0.0039     |
# |    std                  | 1.06        |
# |    value_loss           | 1.35        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -48.7       |
# |    success_rate         | 0.05        |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 292         |
# |    time_elapsed         | 1035        |
# |    total_timesteps      | 299008      |
# | train/                  |             |
# |    approx_kl            | 0.006246848 |
# |    clip_fraction        | 0.0117      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.93       |
# |    explained_variance   | 0.00084     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.054      |
# |    n_updates            | 2910        |
# |    policy_gradient_loss | -0.00249    |
# |    std                  | 1.07        |
# |    value_loss           | 0.0313      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -48.9        |
# |    success_rate         | 0.04         |
# | time/                   |              |
# |    fps                  | 288          |
# |    iterations           | 293          |
# |    time_elapsed         | 1038         |
# |    total_timesteps      | 300032       |
# | train/                  |              |
# |    approx_kl            | 0.0017716466 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.93        |
# |    explained_variance   | -6.13e-05    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.596        |
# |    n_updates            | 2920         |
# |    policy_gradient_loss | -0.000594    |
# |    std                  | 1.06         |
# |    value_loss           | 0.87         |
# ------------------------------------------

# %% [markdown]
# 🔵 CELL 5 — Load Model for Evaluation (Human Render)

# %%
eval_env = gym.make("FetchReach-v4", render_mode="human")
model = PPO.load("ppo_fetchreach", env=eval_env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# 🔵 CELL 6 — Rollout Visualization + Distance Tracking
#
# This is excellent — we’ll just formalize it.

# %%
# eval_env = gym.make("FetchReach-v4", render_mode="human")
# model = PPO.load("ppo_fetchreach", env=eval_env)

obs, info = eval_env.reset()

distances = []
rewards = []

for step in range(600):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = eval_env.step(action)

    achieved = obs["achieved_goal"]
    desired = obs["desired_goal"]
    dist = np.linalg.norm(achieved - desired)

    distances.append(dist)
    rewards.append(reward)

    print(f"{step:03d} | distance={dist:.4f} | reward={reward}")

    time.sleep(0.01)

    if terminated or truncated:
        obs, info = eval_env.reset()

eval_env.close()
# Out:
# 000 | distance=0.1876 | reward=-1.0
# 001 | distance=0.1756 | reward=-1.0
# 002 | distance=0.1650 | reward=-1.0
# 003 | distance=0.1558 | reward=-1.0
# 004 | distance=0.1479 | reward=-1.0
# 005 | distance=0.1417 | reward=-1.0
# 006 | distance=0.1370 | reward=-1.0
# 007 | distance=0.1343 | reward=-1.0
# 008 | distance=0.1326 | reward=-1.0
# 009 | distance=0.1310 | reward=-1.0
# 010 | distance=0.1294 | reward=-1.0
# 011 | distance=0.1278 | reward=-1.0
# 012 | distance=0.1263 | reward=-1.0
# 013 | distance=0.1248 | reward=-1.0
# 014 | distance=0.1233 | reward=-1.0
# 015 | distance=0.1219 | reward=-1.0
# 016 | distance=0.1204 | reward=-1.0
# 017 | distance=0.1191 | reward=-1.0
# 018 | distance=0.1177 | reward=-1.0
# 019 | distance=0.1164 | reward=-1.0
# 020 | distance=0.1151 | reward=-1.0
# 021 | distance=0.1138 | reward=-1.0
# 022 | distance=0.1126 | reward=-1.0
# 023 | distance=0.1113 | reward=-1.0
# 024 | distance=0.1102 | reward=-1.0
# 025 | distance=0.1090 | reward=-1.0
# 026 | distance=0.1078 | reward=-1.0
# 027 | distance=0.1067 | reward=-1.0
# 028 | distance=0.1056 | reward=-1.0
# 029 | distance=0.1045 | reward=-1.0
# 030 | distance=0.1035 | reward=-1.0
# 031 | distance=0.1024 | reward=-1.0
# 032 | distance=0.1014 | reward=-1.0
# 033 | distance=0.1004 | reward=-1.0
# 034 | distance=0.0995 | reward=-1.0
# 035 | distance=0.0985 | reward=-1.0
# 036 | distance=0.0976 | reward=-1.0
# 037 | distance=0.0967 | reward=-1.0
# 038 | distance=0.0958 | reward=-1.0
# 039 | distance=0.0949 | reward=-1.0
# 040 | distance=0.0940 | reward=-1.0
# 041 | distance=0.0932 | reward=-1.0
# 042 | distance=0.0924 | reward=-1.0
# 043 | distance=0.0916 | reward=-1.0
# 044 | distance=0.0908 | reward=-1.0
# 045 | distance=0.0900 | reward=-1.0
# 046 | distance=0.0892 | reward=-1.0
# 047 | distance=0.0885 | reward=-1.0
# 048 | distance=0.0878 | reward=-1.0
# 049 | distance=0.0871 | reward=-1.0
# 050 | distance=0.1748 | reward=-1.0
# 051 | distance=0.1782 | reward=-1.0
# 052 | distance=0.1826 | reward=-1.0
# 053 | distance=0.1879 | reward=-1.0
# 054 | distance=0.1939 | reward=-1.0
# 055 | distance=0.2004 | reward=-1.0
# 056 | distance=0.2074 | reward=-1.0
# 057 | distance=0.2148 | reward=-1.0
# 058 | distance=0.2171 | reward=-1.0
# 059 | distance=0.2164 | reward=-1.0
# 060 | distance=0.2159 | reward=-1.0
# 061 | distance=0.2155 | reward=-1.0
# 062 | distance=0.2150 | reward=-1.0
# 063 | distance=0.2146 | reward=-1.0
# 064 | distance=0.2142 | reward=-1.0
# 065 | distance=0.2138 | reward=-1.0
# 066 | distance=0.2134 | reward=-1.0
# 067 | distance=0.2130 | reward=-1.0
# 068 | distance=0.2126 | reward=-1.0
# 069 | distance=0.2122 | reward=-1.0
# 070 | distance=0.2119 | reward=-1.0
# 071 | distance=0.2115 | reward=-1.0
# 072 | distance=0.2111 | reward=-1.0
# 073 | distance=0.2108 | reward=-1.0
# 074 | distance=0.2104 | reward=-1.0
# 075 | distance=0.2101 | reward=-1.0
# 076 | distance=0.2097 | reward=-1.0
# 077 | distance=0.2094 | reward=-1.0
# 078 | distance=0.2090 | reward=-1.0
# 079 | distance=0.2087 | reward=-1.0
# 080 | distance=0.2084 | reward=-1.0
# 081 | distance=0.2080 | reward=-1.0
# 082 | distance=0.2077 | reward=-1.0
# 083 | distance=0.2074 | reward=-1.0
# 084 | distance=0.2071 | reward=-1.0
# 085 | distance=0.2068 | reward=-1.0
# 086 | distance=0.2064 | reward=-1.0
# 087 | distance=0.2061 | reward=-1.0
# 088 | distance=0.2058 | reward=-1.0
# 089 | distance=0.2055 | reward=-1.0
# 090 | distance=0.2052 | reward=-1.0
# 091 | distance=0.2049 | reward=-1.0
# 092 | distance=0.2046 | reward=-1.0
# 093 | distance=0.2044 | reward=-1.0
# 094 | distance=0.2041 | reward=-1.0
# 095 | distance=0.2038 | reward=-1.0
# 096 | distance=0.2035 | reward=-1.0
# 097 | distance=0.2032 | reward=-1.0
# 098 | distance=0.2029 | reward=-1.0
# 099 | distance=0.2027 | reward=-1.0
# 100 | distance=0.1812 | reward=-1.0
# 101 | distance=0.1938 | reward=-1.0
# 102 | distance=0.2063 | reward=-1.0
# 103 | distance=0.2187 | reward=-1.0
# 104 | distance=0.2311 | reward=-1.0
# 105 | distance=0.2433 | reward=-1.0
# 106 | distance=0.2554 | reward=-1.0
# 107 | distance=0.2672 | reward=-1.0
# 108 | distance=0.2703 | reward=-1.0
# 109 | distance=0.2700 | reward=-1.0
# 110 | distance=0.2700 | reward=-1.0
# 111 | distance=0.2700 | reward=-1.0
# 112 | distance=0.2700 | reward=-1.0
# 113 | distance=0.2700 | reward=-1.0
# 114 | distance=0.2700 | reward=-1.0
# 115 | distance=0.2700 | reward=-1.0
# 116 | distance=0.2700 | reward=-1.0
# 117 | distance=0.2700 | reward=-1.0
# 118 | distance=0.2700 | reward=-1.0
# 119 | distance=0.2700 | reward=-1.0
# 120 | distance=0.2701 | reward=-1.0
# 121 | distance=0.2701 | reward=-1.0
# 122 | distance=0.2701 | reward=-1.0
# 123 | distance=0.2701 | reward=-1.0
# 124 | distance=0.2701 | reward=-1.0
# 125 | distance=0.2701 | reward=-1.0
# 126 | distance=0.2701 | reward=-1.0
# 127 | distance=0.2701 | reward=-1.0
# 128 | distance=0.2701 | reward=-1.0
# 129 | distance=0.2701 | reward=-1.0
# 130 | distance=0.2701 | reward=-1.0
# 131 | distance=0.2701 | reward=-1.0
# 132 | distance=0.2701 | reward=-1.0
# 133 | distance=0.2701 | reward=-1.0
# 134 | distance=0.2701 | reward=-1.0
# 135 | distance=0.2701 | reward=-1.0
# 136 | distance=0.2701 | reward=-1.0
# 137 | distance=0.2702 | reward=-1.0
# 138 | distance=0.2702 | reward=-1.0
# 139 | distance=0.2702 | reward=-1.0
# 140 | distance=0.2702 | reward=-1.0
# 141 | distance=0.2702 | reward=-1.0
# 142 | distance=0.2702 | reward=-1.0
# 143 | distance=0.2702 | reward=-1.0
# 144 | distance=0.2702 | reward=-1.0
# 145 | distance=0.2702 | reward=-1.0
# 146 | distance=0.2702 | reward=-1.0
# 147 | distance=0.2702 | reward=-1.0
# 148 | distance=0.2702 | reward=-1.0
# 149 | distance=0.2702 | reward=-1.0
# 150 | distance=0.1554 | reward=-1.0
# 151 | distance=0.1625 | reward=-1.0
# 152 | distance=0.1702 | reward=-1.0
# 153 | distance=0.1786 | reward=-1.0
# 154 | distance=0.1874 | reward=-1.0
# 155 | distance=0.1965 | reward=-1.0
# 156 | distance=0.2059 | reward=-1.0
# 157 | distance=0.2154 | reward=-1.0
# 158 | distance=0.2226 | reward=-1.0
# 159 | distance=0.2217 | reward=-1.0
# 160 | distance=0.2211 | reward=-1.0
# 161 | distance=0.2206 | reward=-1.0
# 162 | distance=0.2201 | reward=-1.0
# 163 | distance=0.2197 | reward=-1.0
# 164 | distance=0.2193 | reward=-1.0
# 165 | distance=0.2188 | reward=-1.0
# 166 | distance=0.2184 | reward=-1.0
# 167 | distance=0.2180 | reward=-1.0
# 168 | distance=0.2176 | reward=-1.0
# 169 | distance=0.2173 | reward=-1.0
# 170 | distance=0.2169 | reward=-1.0
# 171 | distance=0.2165 | reward=-1.0
# 172 | distance=0.2162 | reward=-1.0
# 173 | distance=0.2159 | reward=-1.0
# 174 | distance=0.2155 | reward=-1.0
# 175 | distance=0.2152 | reward=-1.0
# 176 | distance=0.2149 | reward=-1.0
# 177 | distance=0.2146 | reward=-1.0
# 178 | distance=0.2143 | reward=-1.0
# 179 | distance=0.2140 | reward=-1.0
# 180 | distance=0.2138 | reward=-1.0
# 181 | distance=0.2135 | reward=-1.0
# 182 | distance=0.2132 | reward=-1.0
# 183 | distance=0.2130 | reward=-1.0
# 184 | distance=0.2127 | reward=-1.0
# 185 | distance=0.2125 | reward=-1.0
# 186 | distance=0.2122 | reward=-1.0
# 187 | distance=0.2120 | reward=-1.0
# 188 | distance=0.2118 | reward=-1.0
# 189 | distance=0.2116 | reward=-1.0
# 190 | distance=0.2114 | reward=-1.0
# 191 | distance=0.2112 | reward=-1.0
# 192 | distance=0.2109 | reward=-1.0
# 193 | distance=0.2108 | reward=-1.0
# 194 | distance=0.2106 | reward=-1.0
# 195 | distance=0.2104 | reward=-1.0
# 196 | distance=0.2102 | reward=-1.0
# 197 | distance=0.2100 | reward=-1.0
# 198 | distance=0.2098 | reward=-1.0
# 199 | distance=0.2097 | reward=-1.0
# 200 | distance=0.1800 | reward=-1.0
# 201 | distance=0.1655 | reward=-1.0
# 202 | distance=0.1521 | reward=-1.0
# 203 | distance=0.1398 | reward=-1.0
# 204 | distance=0.1287 | reward=-1.0
# 205 | distance=0.1189 | reward=-1.0
# 206 | distance=0.1108 | reward=-1.0
# 207 | distance=0.1060 | reward=-1.0
# 208 | distance=0.1043 | reward=-1.0
# 209 | distance=0.1025 | reward=-1.0
# 210 | distance=0.1007 | reward=-1.0
# 211 | distance=0.0990 | reward=-1.0
# 212 | distance=0.0973 | reward=-1.0
# 213 | distance=0.0956 | reward=-1.0
# 214 | distance=0.0939 | reward=-1.0
# 215 | distance=0.0923 | reward=-1.0
# 216 | distance=0.0907 | reward=-1.0
# 217 | distance=0.0891 | reward=-1.0
# 218 | distance=0.0875 | reward=-1.0
# 219 | distance=0.0860 | reward=-1.0
# 220 | distance=0.0845 | reward=-1.0
# 221 | distance=0.0830 | reward=-1.0
# 222 | distance=0.0816 | reward=-1.0
# 223 | distance=0.0801 | reward=-1.0
# 224 | distance=0.0787 | reward=-1.0
# 225 | distance=0.0774 | reward=-1.0
# 226 | distance=0.0760 | reward=-1.0
# 227 | distance=0.0747 | reward=-1.0
# 228 | distance=0.0734 | reward=-1.0
# 229 | distance=0.0721 | reward=-1.0
# 230 | distance=0.0708 | reward=-1.0
# 231 | distance=0.0696 | reward=-1.0
# 232 | distance=0.0683 | reward=-1.0
# 233 | distance=0.0671 | reward=-1.0
# 234 | distance=0.0659 | reward=-1.0
# 235 | distance=0.0648 | reward=-1.0
# 236 | distance=0.0636 | reward=-1.0
# 237 | distance=0.0625 | reward=-1.0
# 238 | distance=0.0614 | reward=-1.0
# 239 | distance=0.0603 | reward=-1.0
# 240 | distance=0.0593 | reward=-1.0
# 241 | distance=0.0582 | reward=-1.0
# 242 | distance=0.0572 | reward=-1.0
# 243 | distance=0.0562 | reward=-1.0
# 244 | distance=0.0552 | reward=-1.0
# 245 | distance=0.0542 | reward=-1.0
# 246 | distance=0.0533 | reward=-1.0
# 247 | distance=0.0523 | reward=-1.0
# 248 | distance=0.0514 | reward=-1.0
# 249 | distance=0.0505 | reward=-1.0
# 250 | distance=0.1570 | reward=-1.0
# 251 | distance=0.1708 | reward=-1.0
# 252 | distance=0.1843 | reward=-1.0
# 253 | distance=0.1975 | reward=-1.0
# 254 | distance=0.2104 | reward=-1.0
# 255 | distance=0.2231 | reward=-1.0
# 256 | distance=0.2355 | reward=-1.0
# 257 | distance=0.2475 | reward=-1.0
# 258 | distance=0.2572 | reward=-1.0
# 259 | distance=0.2567 | reward=-1.0
# 260 | distance=0.2565 | reward=-1.0
# 261 | distance=0.2565 | reward=-1.0
# 262 | distance=0.2564 | reward=-1.0
# 263 | distance=0.2564 | reward=-1.0
# 264 | distance=0.2564 | reward=-1.0
# 265 | distance=0.2563 | reward=-1.0
# 266 | distance=0.2563 | reward=-1.0
# 267 | distance=0.2563 | reward=-1.0
# 268 | distance=0.2563 | reward=-1.0
# 269 | distance=0.2562 | reward=-1.0
# 270 | distance=0.2562 | reward=-1.0
# 271 | distance=0.2562 | reward=-1.0
# 272 | distance=0.2562 | reward=-1.0
# 273 | distance=0.2562 | reward=-1.0
# 274 | distance=0.2562 | reward=-1.0
# 275 | distance=0.2562 | reward=-1.0
# 276 | distance=0.2561 | reward=-1.0
# 277 | distance=0.2561 | reward=-1.0
# 278 | distance=0.2561 | reward=-1.0
# 279 | distance=0.2561 | reward=-1.0
# 280 | distance=0.2561 | reward=-1.0
# 281 | distance=0.2561 | reward=-1.0
# 282 | distance=0.2561 | reward=-1.0
# 283 | distance=0.2561 | reward=-1.0
# 284 | distance=0.2561 | reward=-1.0
# 285 | distance=0.2561 | reward=-1.0
# 286 | distance=0.2561 | reward=-1.0
# 287 | distance=0.2561 | reward=-1.0
# 288 | distance=0.2561 | reward=-1.0
# 289 | distance=0.2561 | reward=-1.0
# 290 | distance=0.2561 | reward=-1.0
# 291 | distance=0.2562 | reward=-1.0
# 292 | distance=0.2562 | reward=-1.0
# 293 | distance=0.2562 | reward=-1.0
# 294 | distance=0.2562 | reward=-1.0
# 295 | distance=0.2562 | reward=-1.0
# 296 | distance=0.2562 | reward=-1.0
# 297 | distance=0.2562 | reward=-1.0
# 298 | distance=0.2562 | reward=-1.0
# 299 | distance=0.2562 | reward=-1.0
# 300 | distance=0.1983 | reward=-1.0
# 301 | distance=0.2085 | reward=-1.0
# 302 | distance=0.2190 | reward=-1.0
# 303 | distance=0.2298 | reward=-1.0
# 304 | distance=0.2408 | reward=-1.0
# 305 | distance=0.2518 | reward=-1.0
# 306 | distance=0.2628 | reward=-1.0
# 307 | distance=0.2732 | reward=-1.0
# 308 | distance=0.2733 | reward=-1.0
# 309 | distance=0.2729 | reward=-1.0
# 310 | distance=0.2727 | reward=-1.0
# 311 | distance=0.2725 | reward=-1.0
# 312 | distance=0.2723 | reward=-1.0
# 313 | distance=0.2721 | reward=-1.0
# 314 | distance=0.2720 | reward=-1.0
# 315 | distance=0.2718 | reward=-1.0
# 316 | distance=0.2716 | reward=-1.0
# 317 | distance=0.2714 | reward=-1.0
# 318 | distance=0.2713 | reward=-1.0
# 319 | distance=0.2711 | reward=-1.0
# 320 | distance=0.2709 | reward=-1.0
# 321 | distance=0.2708 | reward=-1.0
# 322 | distance=0.2706 | reward=-1.0
# 323 | distance=0.2705 | reward=-1.0
# 324 | distance=0.2703 | reward=-1.0
# 325 | distance=0.2702 | reward=-1.0
# 326 | distance=0.2700 | reward=-1.0
# 327 | distance=0.2699 | reward=-1.0
# 328 | distance=0.2697 | reward=-1.0
# 329 | distance=0.2696 | reward=-1.0
# 330 | distance=0.2695 | reward=-1.0
# 331 | distance=0.2693 | reward=-1.0
# 332 | distance=0.2692 | reward=-1.0
# 333 | distance=0.2691 | reward=-1.0
# 334 | distance=0.2690 | reward=-1.0
# 335 | distance=0.2688 | reward=-1.0
# 336 | distance=0.2687 | reward=-1.0
# 337 | distance=0.2686 | reward=-1.0
# 338 | distance=0.2685 | reward=-1.0
# 339 | distance=0.2684 | reward=-1.0
# 340 | distance=0.2683 | reward=-1.0
# 341 | distance=0.2682 | reward=-1.0
# 342 | distance=0.2681 | reward=-1.0
# 343 | distance=0.2680 | reward=-1.0
# 344 | distance=0.2679 | reward=-1.0
# 345 | distance=0.2678 | reward=-1.0
# 346 | distance=0.2677 | reward=-1.0
# 347 | distance=0.2676 | reward=-1.0
# 348 | distance=0.2675 | reward=-1.0
# 349 | distance=0.2674 | reward=-1.0
# 350 | distance=0.1418 | reward=-1.0
# 351 | distance=0.1395 | reward=-1.0
# 352 | distance=0.1389 | reward=-1.0
# 353 | distance=0.1400 | reward=-1.0
# 354 | distance=0.1425 | reward=-1.0
# 355 | distance=0.1463 | reward=-1.0
# 356 | distance=0.1512 | reward=-1.0
# 357 | distance=0.1570 | reward=-1.0
# 358 | distance=0.1569 | reward=-1.0
# 359 | distance=0.1560 | reward=-1.0
# 360 | distance=0.1553 | reward=-1.0
# 361 | distance=0.1546 | reward=-1.0
# 362 | distance=0.1539 | reward=-1.0
# 363 | distance=0.1533 | reward=-1.0
# 364 | distance=0.1526 | reward=-1.0
# 365 | distance=0.1520 | reward=-1.0
# 366 | distance=0.1514 | reward=-1.0
# 367 | distance=0.1508 | reward=-1.0
# 368 | distance=0.1502 | reward=-1.0
# 369 | distance=0.1496 | reward=-1.0
# 370 | distance=0.1490 | reward=-1.0
# 371 | distance=0.1485 | reward=-1.0
# 372 | distance=0.1479 | reward=-1.0
# 373 | distance=0.1474 | reward=-1.0
# 374 | distance=0.1469 | reward=-1.0
# 375 | distance=0.1464 | reward=-1.0
# 376 | distance=0.1459 | reward=-1.0
# 377 | distance=0.1454 | reward=-1.0
# 378 | distance=0.1450 | reward=-1.0
# 379 | distance=0.1445 | reward=-1.0
# 380 | distance=0.1441 | reward=-1.0
# 381 | distance=0.1436 | reward=-1.0
# 382 | distance=0.1432 | reward=-1.0
# 383 | distance=0.1428 | reward=-1.0
# 384 | distance=0.1424 | reward=-1.0
# 385 | distance=0.1420 | reward=-1.0
# 386 | distance=0.1416 | reward=-1.0
# 387 | distance=0.1412 | reward=-1.0
# 388 | distance=0.1409 | reward=-1.0
# 389 | distance=0.1405 | reward=-1.0
# 390 | distance=0.1401 | reward=-1.0
# 391 | distance=0.1398 | reward=-1.0
# 392 | distance=0.1394 | reward=-1.0
# 393 | distance=0.1391 | reward=-1.0
# 394 | distance=0.1388 | reward=-1.0
# 395 | distance=0.1385 | reward=-1.0
# 396 | distance=0.1381 | reward=-1.0
# 397 | distance=0.1378 | reward=-1.0
# 398 | distance=0.1375 | reward=-1.0
# 399 | distance=0.1372 | reward=-1.0
# 400 | distance=0.1338 | reward=-1.0
# 401 | distance=0.1351 | reward=-1.0
# 402 | distance=0.1382 | reward=-1.0
# 403 | distance=0.1428 | reward=-1.0
# 404 | distance=0.1486 | reward=-1.0
# 405 | distance=0.1555 | reward=-1.0
# 406 | distance=0.1632 | reward=-1.0
# 407 | distance=0.1715 | reward=-1.0
# 408 | distance=0.1737 | reward=-1.0
# 409 | distance=0.1726 | reward=-1.0
# 410 | distance=0.1719 | reward=-1.0
# 411 | distance=0.1713 | reward=-1.0
# 412 | distance=0.1706 | reward=-1.0
# 413 | distance=0.1700 | reward=-1.0
# 414 | distance=0.1695 | reward=-1.0
# 415 | distance=0.1689 | reward=-1.0
# 416 | distance=0.1683 | reward=-1.0
# 417 | distance=0.1678 | reward=-1.0
# 418 | distance=0.1673 | reward=-1.0
# 419 | distance=0.1668 | reward=-1.0
# 420 | distance=0.1663 | reward=-1.0
# 421 | distance=0.1659 | reward=-1.0
# 422 | distance=0.1654 | reward=-1.0
# 423 | distance=0.1650 | reward=-1.0
# 424 | distance=0.1646 | reward=-1.0
# 425 | distance=0.1642 | reward=-1.0
# 426 | distance=0.1638 | reward=-1.0
# 427 | distance=0.1634 | reward=-1.0
# 428 | distance=0.1630 | reward=-1.0
# 429 | distance=0.1627 | reward=-1.0
# 430 | distance=0.1624 | reward=-1.0
# 431 | distance=0.1620 | reward=-1.0
# 432 | distance=0.1617 | reward=-1.0
# 433 | distance=0.1614 | reward=-1.0
# 434 | distance=0.1611 | reward=-1.0
# 435 | distance=0.1608 | reward=-1.0
# 436 | distance=0.1606 | reward=-1.0
# 437 | distance=0.1603 | reward=-1.0
# 438 | distance=0.1600 | reward=-1.0
# 439 | distance=0.1598 | reward=-1.0
# 440 | distance=0.1596 | reward=-1.0
# 441 | distance=0.1593 | reward=-1.0
# 442 | distance=0.1591 | reward=-1.0
# 443 | distance=0.1589 | reward=-1.0
# 444 | distance=0.1587 | reward=-1.0
# 445 | distance=0.1585 | reward=-1.0
# 446 | distance=0.1583 | reward=-1.0
# 447 | distance=0.1581 | reward=-1.0
# 448 | distance=0.1579 | reward=-1.0
# 449 | distance=0.1578 | reward=-1.0
# 450 | distance=0.1826 | reward=-1.0
# 451 | distance=0.1917 | reward=-1.0
# 452 | distance=0.2012 | reward=-1.0
# 453 | distance=0.2110 | reward=-1.0
# 454 | distance=0.2210 | reward=-1.0
# 455 | distance=0.2312 | reward=-1.0
# 456 | distance=0.2415 | reward=-1.0
# 457 | distance=0.2517 | reward=-1.0
# 458 | distance=0.2613 | reward=-1.0
# 459 | distance=0.2610 | reward=-1.0
# 460 | distance=0.2605 | reward=-1.0
# 461 | distance=0.2602 | reward=-1.0
# 462 | distance=0.2599 | reward=-1.0
# 463 | distance=0.2596 | reward=-1.0
# 464 | distance=0.2593 | reward=-1.0
# 465 | distance=0.2590 | reward=-1.0
# 466 | distance=0.2588 | reward=-1.0
# 467 | distance=0.2585 | reward=-1.0
# 468 | distance=0.2583 | reward=-1.0
# 469 | distance=0.2580 | reward=-1.0
# 470 | distance=0.2578 | reward=-1.0
# 471 | distance=0.2576 | reward=-1.0
# 472 | distance=0.2574 | reward=-1.0
# 473 | distance=0.2572 | reward=-1.0
# 474 | distance=0.2570 | reward=-1.0
# 475 | distance=0.2568 | reward=-1.0
# 476 | distance=0.2566 | reward=-1.0
# 477 | distance=0.2565 | reward=-1.0
# 478 | distance=0.2563 | reward=-1.0
# 479 | distance=0.2562 | reward=-1.0
# 480 | distance=0.2560 | reward=-1.0
# 481 | distance=0.2559 | reward=-1.0
# 482 | distance=0.2557 | reward=-1.0
# 483 | distance=0.2556 | reward=-1.0
# 484 | distance=0.2555 | reward=-1.0
# 485 | distance=0.2554 | reward=-1.0
# 486 | distance=0.2552 | reward=-1.0
# 487 | distance=0.2551 | reward=-1.0
# 488 | distance=0.2550 | reward=-1.0
# 489 | distance=0.2549 | reward=-1.0
# 490 | distance=0.2548 | reward=-1.0
# 491 | distance=0.2547 | reward=-1.0
# 492 | distance=0.2546 | reward=-1.0
# 493 | distance=0.2546 | reward=-1.0
# 494 | distance=0.2545 | reward=-1.0
# 495 | distance=0.2544 | reward=-1.0
# 496 | distance=0.2543 | reward=-1.0
# 497 | distance=0.2543 | reward=-1.0
# 498 | distance=0.2542 | reward=-1.0
# 499 | distance=0.2541 | reward=-1.0
# 500 | distance=0.2070 | reward=-1.0
# 501 | distance=0.2103 | reward=-1.0
# 502 | distance=0.2145 | reward=-1.0
# 503 | distance=0.2193 | reward=-1.0
# 504 | distance=0.2247 | reward=-1.0
# 505 | distance=0.2307 | reward=-1.0
# 506 | distance=0.2370 | reward=-1.0
# 507 | distance=0.2436 | reward=-1.0
# 508 | distance=0.2477 | reward=-1.0
# 509 | distance=0.2468 | reward=-1.0
# 510 | distance=0.2461 | reward=-1.0
# 511 | distance=0.2455 | reward=-1.0
# 512 | distance=0.2449 | reward=-1.0
# 513 | distance=0.2444 | reward=-1.0
# 514 | distance=0.2438 | reward=-1.0
# 515 | distance=0.2433 | reward=-1.0
# 516 | distance=0.2427 | reward=-1.0
# 517 | distance=0.2422 | reward=-1.0
# 518 | distance=0.2416 | reward=-1.0
# 519 | distance=0.2411 | reward=-1.0
# 520 | distance=0.2406 | reward=-1.0
# 521 | distance=0.2401 | reward=-1.0
# 522 | distance=0.2396 | reward=-1.0
# 523 | distance=0.2391 | reward=-1.0
# 524 | distance=0.2386 | reward=-1.0
# 525 | distance=0.2382 | reward=-1.0
# 526 | distance=0.2377 | reward=-1.0
# 527 | distance=0.2372 | reward=-1.0
# 528 | distance=0.2368 | reward=-1.0
# 529 | distance=0.2363 | reward=-1.0
# 530 | distance=0.2359 | reward=-1.0
# 531 | distance=0.2354 | reward=-1.0
# 532 | distance=0.2350 | reward=-1.0
# 533 | distance=0.2346 | reward=-1.0
# 534 | distance=0.2341 | reward=-1.0
# 535 | distance=0.2337 | reward=-1.0
# 536 | distance=0.2333 | reward=-1.0
# 537 | distance=0.2329 | reward=-1.0
# 538 | distance=0.2325 | reward=-1.0
# 539 | distance=0.2321 | reward=-1.0
# 540 | distance=0.2317 | reward=-1.0
# 541 | distance=0.2313 | reward=-1.0
# 542 | distance=0.2309 | reward=-1.0
# 543 | distance=0.2305 | reward=-1.0
# 544 | distance=0.2302 | reward=-1.0
# 545 | distance=0.2298 | reward=-1.0
# 546 | distance=0.2294 | reward=-1.0
# 547 | distance=0.2291 | reward=-1.0
# 548 | distance=0.2287 | reward=-1.0
# 549 | distance=0.2283 | reward=-1.0
# 550 | distance=0.1427 | reward=-1.0
# 551 | distance=0.1497 | reward=-1.0
# 552 | distance=0.1575 | reward=-1.0
# 553 | distance=0.1659 | reward=-1.0
# 554 | distance=0.1749 | reward=-1.0
# 555 | distance=0.1842 | reward=-1.0
# 556 | distance=0.1938 | reward=-1.0
# 557 | distance=0.2035 | reward=-1.0
# 558 | distance=0.2099 | reward=-1.0
# 559 | distance=0.2088 | reward=-1.0
# 560 | distance=0.2083 | reward=-1.0
# 561 | distance=0.2078 | reward=-1.0
# 562 | distance=0.2074 | reward=-1.0
# 563 | distance=0.2070 | reward=-1.0
# 564 | distance=0.2066 | reward=-1.0
# 565 | distance=0.2062 | reward=-1.0
# 566 | distance=0.2058 | reward=-1.0
# 567 | distance=0.2054 | reward=-1.0
# 568 | distance=0.2051 | reward=-1.0
# 569 | distance=0.2047 | reward=-1.0
# 570 | distance=0.2044 | reward=-1.0
# 571 | distance=0.2041 | reward=-1.0
# 572 | distance=0.2037 | reward=-1.0
# 573 | distance=0.2034 | reward=-1.0
# 574 | distance=0.2031 | reward=-1.0
# 575 | distance=0.2028 | reward=-1.0
# 576 | distance=0.2026 | reward=-1.0
# 577 | distance=0.2023 | reward=-1.0
# 578 | distance=0.2020 | reward=-1.0
# 579 | distance=0.2018 | reward=-1.0
# 580 | distance=0.2015 | reward=-1.0
# 581 | distance=0.2013 | reward=-1.0
# 582 | distance=0.2010 | reward=-1.0
# 583 | distance=0.2008 | reward=-1.0
# 584 | distance=0.2006 | reward=-1.0
# 585 | distance=0.2003 | reward=-1.0
# 586 | distance=0.2001 | reward=-1.0
# 587 | distance=0.1999 | reward=-1.0
# 588 | distance=0.1997 | reward=-1.0
# 589 | distance=0.1995 | reward=-1.0
# 590 | distance=0.1993 | reward=-1.0
# 591 | distance=0.1991 | reward=-1.0
# 592 | distance=0.1990 | reward=-1.0
# 593 | distance=0.1988 | reward=-1.0
# 594 | distance=0.1986 | reward=-1.0
# 595 | distance=0.1984 | reward=-1.0
# 596 | distance=0.1983 | reward=-1.0
# 597 | distance=0.1981 | reward=-1.0
# 598 | distance=0.1980 | reward=-1.0
# 599 | distance=0.1978 | reward=-1.0

# %% [markdown]
# 🔵 CELL 7 — Plot Distance-to-Goal Over Time (IMPORTANT)

# %%
plt.figure(figsize=(8,4))
plt.plot(distances)
plt.xlabel("Step")
plt.ylabel("Distance to Goal")
plt.title("Distance to Goal During Evaluation Rollout")
plt.grid(True)
plt.show()

# %% [markdown]
# 🔵 CELL 8 — Formal Evaluation (100 Episodes)
#
# This is where comparison metrics come from.

# %%
eval_env = gym.make("FetchReach-v4")
model.set_env(eval_env)

episode_rewards = []
episode_success = []
episode_lengths = []
final_distances = []
action_magnitudes = []

N_EVAL_EPISODES = 100

for ep in range(N_EVAL_EPISODES):
    obs, info = eval_env.reset()
    done = False
    total_reward = 0
    steps = 0
    actions = []

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = eval_env.step(action)

        total_reward += reward
        steps += 1
        actions.append(np.linalg.norm(action))

        done = terminated or truncated

    episode_rewards.append(total_reward)
    episode_success.append(info.get("is_success", 0))
    episode_lengths.append(steps)
    final_distances.append(np.linalg.norm(
        obs["achieved_goal"] - obs["desired_goal"]
    ))
    action_magnitudes.append(np.mean(actions))
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# 🔵 CELL 9 — Core Numerical Metrics (REPORT THESE)

# %%
print("Average Episodic Reward:", np.mean(episode_rewards))
print("Reward Std Dev:", np.std(episode_rewards))

print(f"Success Rate: {np.mean(episode_success)*100:.2f}%")

print("Average Episode Length:", np.mean(episode_lengths))

print("Mean Final Distance:", np.mean(final_distances))
print("Final Distance Std:", np.std(final_distances))

print("Mean Action Magnitude:", np.mean(action_magnitudes))
# Out:
# Average Episodic Reward: -48.94
# Reward Std Dev: 6.2222505
# Success Rate: 2.00%
# Average Episode Length: 50.0
# Mean Final Distance: 0.15733520432044634
# Final Distance Std: 0.06234644648164824
# Mean Action Magnitude: 0.6458805

# %% [markdown]
# 🔵 CELL 10 — Success Rate Over Episodes

# %%
success_curve = np.cumsum(episode_success) / np.arange(1, len(episode_success)+1)

plt.figure(figsize=(8,4))
plt.plot(success_curve)
plt.xlabel("Episode")
plt.ylabel("Success Rate")
plt.title("Success Rate Progression")
plt.grid(True)
plt.show()

# %% [markdown]
# 🔵 CELL 11 — Reward Distribution (Stability)

# %%
plt.figure(figsize=(6,4))
plt.hist(episode_rewards, bins=20)
plt.xlabel("Episodic Reward")
plt.ylabel("Frequency")
plt.title("Reward Distribution")
plt.show()

# %% [markdown]
# 🔵 CELL 12 — Convergence Time (Impressive Metric)

# %%
window = 20
rolling_success = np.convolve(
    episode_success,
    np.ones(window)/window,
    mode="valid"
)

threshold = 0.8
conv_episode = np.argmax(rolling_success >= threshold)

print("Convergence Episode (80% success):", conv_episode)
# Out:
# Convergence Episode (80% success): 0
